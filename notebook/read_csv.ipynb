# %%
import pandas as pd
import sys

# %%
pd.set_option('display.max_rows', 30)   #data output display settings

# %%
annual_delta_gdpc = pd.read_csv('../data/API_NY.GDP.PCAP.KD.ZG_DS2_en_csv_v2_41031.csv', skiprows=4)

# %%
annual_delta_gdpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 64 columns):
# Country Name      264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              0 non-null float64
# 1961              124 non-null float64
# 1962              126 non-null float64
# 1963              126 non-null float64
# 1964              126 non-null float64
# 1965              126 non-null float64
# 1966              135 non-null float64
# 1967              139 non-null float64
# 1968              140 non-null float64
# 1969              144 non-null float64
# 1970              144 non-null float64
# 1971              158 non-null float64
# 1972              158 non-null float64
# 1973              158 non-null float64
# 1974              158 non-null float64
# 1975              160 non-null float64
# 1976              164 non-null float64
# ...

# %%
annual_delta_gdpc.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', 'Unnamed: 63'],
#       dtype='object')

# %%
annual_delta_gdpc.tail(20)
# Out:
#                        Country Name Country Code  \
# 244                        Tanzania          TZA
# 245                          Uganda          UGA
# 246                         Ukraine          UKR
# 247             Upper middle income          UMC
# 248                         Uruguay          URY
# 249                   United States          USA
# 250                      Uzbekistan          UZB
# 251  St. Vincent and the Grenadines          VCT
# 252                   Venezuela, RB          VEN
# 253          British Virgin Islands          VGB
# 254           Virgin Islands (U.S.)          VIR
# 255                         Vietnam          VNM
# 256                         Vanuatu          VUT
# 257                           World          WLD
# 258                           Samoa          WSM
# 259                          Kosovo          XKX
# 260                     Yemen, Rep.          YEM
# 261                    South Africa          ZAF
# ...

# %%
#drop columns with all null and not important string columns

annual_delta_gdpc = annual_delta_gdpc.drop(['Country Code','Indicator Name','Indicator Code','1960','Unnamed: 63'], axis=1)

# %%
annual_delta_gdpc.set_index('Country Name')

# %%
annual_delta_gdpc = annual_delta_gdpc.T
annual_delta_gdpc

# %%
annual_delta_gdpc = annual_delta_gdpc.rename(columns=annual_delta_gdpc.iloc[0]).drop(annual_delta_gdpc.index[0])
annual_delta_gdpc

# %%
annual_delta_gdpc.dropna(axis=1, how='all')
annual_delta_gdpc.columns

# %%
subset = annual_delta_gdpc.iloc[:,1:]
subset.head(5)

# %%
empty_row_df = annual_delta_gdpc[subset.isnull().all(1)]
empty_row_df

# %%
empty_countries = list(empty_row_df['Country Name'])
empty_countries

# %%
#annual_delta_gdpc.iloc[:,1:].isnull()
#annual_delta_gdpc.index[annual_delta_gdpc.isnull().all(1)]
# idx = df.index[df.isnull().all(1)]
# nans = df.ix[idx]
# nans
#annual_delta_gdpc[annual_delta_gdpc.iloc[:,1:].isnull()]
#annual_delta_gdpc.iloc[:,1:][annual_delta_gdpc.isnull().all(1)]
#annual_delta_gdpc[annual_delta_gdpc.iloc[:,1:].isnull().]#['Country Name'].unique()
annual_delta_gdpc = annual_delta_gdpc[(annual_delta_gdpc['Country Name'] != [x for x in empty_countries])]

# %%
annual_delta_gdpc.loc[df['Country Name'] == 'Monaco']

# %%
#initially dropped columns with any null values
#resulted in all year columns dropped
#insight: some country(ies) gdp per capita not collected into modern times
#df.dropna(axis=1,how='any')

annual_delta_gdpc[annual_delta_gdpc['2018'].isnull()]['Country Name'].unique()

# %%
annual_delta_gdpc.T.head(5)

# %%
annual_delta_gdpc.head(5)
